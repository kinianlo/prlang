# %% [markdown]
# <a href="https://colab.research.google.com/github/kinianlo/prlang/blob/main/archive/verb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PR-like models in langauge

# %% [markdown]
# ### Generate PR-like models with Masked LM

# %%
# !pip install numpy inflect torch transformers git+https://github.com/kinianlo/contextuality.git
# Out:
# Collecting git+https://github.com/kinianlo/contextuality.git
#   Cloning https://github.com/kinianlo/contextuality.git to /tmp/pip-req-build-nday0ews
#   Running command git clone -q https://github.com/kinianlo/contextuality.git /tmp/pip-req-build-nday0ews
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.19.2)
# Requirement already satisfied: picos in /usr/local/lib/python3.7/dist-packages (from Contextuality==0.0.1) (2.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from picos->Contextuality==0.0.1) (1.2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)

# %%
import itertools
import numpy as np
import inflect
import random
import json
import pandas as pd
from tqdm.auto import tqdm
from time import time

from contextuality.model import Model, CyclicScenario

import torch
from transformers import AutoModelForMaskedLM, AutoTokenizer
from transformers import logging
logging.set_verbosity_error()

# %%
def get_probs(sentences_raw, options, model, tokenizer, mask_placeholder='_'):
    """
    Predict a masked word with probability scores for the provided options
    for the mask.
    
    Parameters
    ---------
    sentences_raw : str or (list of str)
    options : (list of str) or (list of (list of str))
    model : MaskedLM
    tokenizer : Tokenizer
    """
    torch.cuda.empty_cache()
    if type(sentences_raw) is str:
        sentences_raw = [sentences_raw]
    if type(options[0]) is str:
        options = [options for s in sentences_raw]
    
    partition_size = 2**8
    n_sentence = len(sentences_raw)
    if n_sentence > partition_size:
        print(f"Processing {n_sentence} sentences. Batching...")
        probs = []
        for i in tqdm(range(0, len(sentences_raw), partition_size)):
            sentences_raw_part = sentences_raw[i:i+partition_size]
            options_part = options[i:i+partition_size]
            probs += get_probs(sentences_raw_part, options_part, model,
                               tokenizer, mask_placeholder=mask_placeholder)
        return probs
        
    # Convert the option words into tokens
    options_token = [[tokenizer.tokenize(op)[0] for op in ops] for ops in options]
    options_id = [[tokenizer.vocab[op] for op in ops] for ops in options_token]
    
    # Replace mask placeholders with the mask token used by the given tokenizer
    sentences = [s.replace(mask_placeholder, tokenizer.mask_token) for s in sentences_raw]
    inputs = tokenizer(sentences, return_tensors='pt', padding=True).to(model.device)
    
    mask_indices = torch.where(inputs["input_ids"] == tokenizer.mask_token_id)
    
    outputs = model(**inputs)
    logits = outputs.logits
    
    mask_logits = logits[mask_indices]
    
    probs = [[] for i in range(len(sentences))]
    
    for i in range(len(mask_indices[0])):
        s_idx, m_idx = mask_indices[0][i], mask_indices[1][i]
        prob = torch.softmax(mask_logits[i][options_id[s_idx]], dim=-1).detach().cpu().numpy()
        prob = dict(zip(options[s_idx], prob))
        probs[s_idx] = prob
        
    if len(probs) == 1:
        probs = probs[0]
    return probs

# %%
# Initialise the language model and its tokenizer
device = "cuda:0" if torch.cuda.is_available() else "cpu"
lm_name = 'bert-base-uncased'
mlm = AutoModelForMaskedLM.from_pretrained(lm_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(lm_name)

# %% [markdown]
# ## The following handles a batch of examples
# Examples should be given in a text file where each row has the format:
#
# ```outcome1 outcome2: observable1 observable2 observable3 observable4 ...```
#
# For example,
#
# ```apple strawberry: sweet red round green big```
#
# For each row, all ordered combinations of 3 observables will be considered in the following.

# %%
def process_topics_file(file_name):
    topics = []
    with open(file_name) as file:
        for row in file:
            if not row.strip():
                continue
            outcomes = [] 
            observables = []
            outcomes_str, observables_str = map(str.strip, row.split(':'))
            outcomes = list(map(str.strip, set(outcomes_str.split(','))))
            observables = list(map(str.strip, set(observables_str.split(','))))
            topics.append((outcomes, observables))
    return topics

def process_schemas_file(file_name):
    schema_options = dict()
    schemas = dict()
    with open(file_name) as file:
        data = json.load(file)
        schema_options = data['options']
        schemas = data['schemas']
    return schema_options, schemas

# %%
def generate_scenarios(topics, schema=None):
    scenarios = []
    for topic in topics:
        outcomes, observables = topic
        out_perm = itertools.permutations(outcomes, 2)
        obs_perm = itertools.permutations(observables, 3)
        scenarios += list(itertools.product(out_perm, obs_perm))
    return scenarios

# %%
def a(word):
    """Return `a` or `an` depending on the given word.
    """
    return inflect.engine().a(word)

def generate_sentences(scenario, schema):
    sentences = []
    o, x = scenario
    if schema == 'adj':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is {x[0]} and the same one is {x[1]}.")
        sentences.append(f"{intro} The _ is {x[1]} and the same one is {x[2]}.")
        sentences.append(f"{intro} The _ is {x[2]} and the other one is {x[0]}.")
    elif schema == 'verb':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is being {x[0]} and the same one is being {x[1]}.")
        sentences.append(f"{intro} The _ is being {x[1]} and the same one is being {x[2]}.")
        sentences.append(f"{intro} The _ is being {x[2]} and the other one is being {x[0]}.")
    elif schema == 'prep':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is {x[0]} and the same one is {x[1]}.")
        sentences.append(f"{intro} The _ is {x[1]} and the same one is {x[2]}.")
        sentences.append(f"{intro} The _ is {x[2]} and the other one is {x[0]}.")
    return sentences

def get_mask_options(scenario, schema):
    o, x = scenario
    return [o for i in range(3)]

# %% [markdown]
# # Load topics files here!

# %%
# %cd
# %rm -rf prlang
# !git clone https://github.com/kinianlo/prlang.git
# %cd prlang
# Out:
# /root
# Cloning into 'prlang'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 93 (delta 46), reused 56 (delta 20), pack-reused 0
# Unpacking objects: 100% (93/93), done.
# /root/prlang

# %%
topics = process_topics_file('data/verb.txt')
schema = 'verb'

print(f'Topics for schema `{schema}`:')
for t in topics:
    print(t)
# Out:
# Topics for schema `verb`:
# (['strawberry', 'apple'], ['rotten', 'sold', 'chilled', 'eaten', 'steamed', 'cooked', 'washed', 'bought'])
# (['dog', 'cat'], ['cleaned', 'bathed', 'chased', 'held', 'touched', 'fed', 'hunted', 'pet', 'watched'])

# %%
df = pd.DataFrame(columns=['nouns', 'modifiers', 'models', 'contextual_models'])

sfs_list = []
sheaf_models_list = []

for topic in topics:
    row = dict()
    scenarios = generate_scenarios([topic], schema)
    print(f"Curent topic: {topic}")
    row['nouns'], row['modifiers'] = topic

    n_scenario = len(scenarios)
    row['models'] = n_scenario
    print(f"Number of scenarios: {n_scenario}")
    
    sentences = [generate_sentences(scen, schema) for scen in scenarios]
    sentences_flat = list(itertools.chain.from_iterable(sentences))

    mask_options = [get_mask_options(scen, schema) for scen in scenarios]
    mask_options_flat = list(itertools.chain.from_iterable(mask_options))

    probs_flat = get_probs(sentences_flat, mask_options_flat, mlm, tokenizer)
    probs = [probs_flat[3*i:3*i+3] for i in range(n_scenario)]

    sheaf_models = []
    cbd_models = []
    sfs = []
    cbds = []
    for i in range(n_scenario):
        outcomes, observables = scenarios[i]
        tri_scenario = CyclicScenario(observables, 2)
        o0, o1 = outcomes
        x0, x1, x2 = observables
        
        table = []
        table.append([probs[i][0][o0], 0, 0, probs[i][0][o1]])
        table.append([probs[i][1][o0], 0, 0, probs[i][1][o1]])
        table.append([0, probs[i][2][o0], probs[i][2][o1], 0])
        
        model = Model(tri_scenario, table)
        sfs.append(model.signalling_fraction())
        cbds.append(model.CbD_measure())
        if sfs[-1] < 1/6:
            sheaf_models.append(model)
            for s in sentences[i]:
                print(s)
            print(model)
            print(f"Signalling fraction: {model.signalling_fraction()}")
            print(f"\\model{{{o0}}}{{{o1}}}{{{x0}}}{{{x1}}}{{{x2}}}{{{probs[i][0][o0]}}}{{{probs[i][1][o0]}}}{{{probs[i][2][o0]}}}")
            print('='*60)
        
        if cbds[-1] > 0:
            cbd_models.append(model)
    sheaf_models_list += sheaf_models
    sfs_list += sfs
    row['contextual_models'] = len(sheaf_models)
    df = df.append(row, ignore_index=True)
# Out:
# Curent topic: (['strawberry', 'apple'], ['rotten', 'sold', 'chilled', 'eaten', 'steamed', 'cooked', 'washed', 'bought'])
# Number of scenarios: 672
# Processing 2016 sentences. Batching...
#   0%|          | 0/8 [00:00<?, ?it/s]
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being chilled.
# There is a strawberry and an apple. The _ is being chilled and the other one is being sold.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4577 0.0000 0.0000 0.5423
# (eaten, chilled) 0.5627 0.0000 0.0000 0.4373
# (chilled, sold) 0.0000 0.4409 0.5591 0.0000
#
# Signalling fraction: 0.12543964248815664
# \model{strawberry}{apple}{sold}{eaten}{chilled}{0.4577459692955017}{0.5627198219299316}{0.44091376662254333}
# ============================================================
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being sold.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4577 0.0000 0.0000 0.5423
# (eaten, steamed) 0.5774 0.0000 0.0000 0.4226
# (steamed, sold) 0.0000 0.4292 0.5708 0.0000
#
# Signalling fraction: 0.1547854542121727
# \model{strawberry}{apple}{sold}{eaten}{steamed}{0.4577459692955017}{0.5773927569389343}{0.4291812479496002}
# ============================================================
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being bought.
# There is a strawberry and an apple. The _ is being bought and the other one is being sold.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4577 0.0000 0.0000 0.5423
# (eaten, bought) 0.4180 0.0000 0.0000 0.5820
# (bought, sold) 0.0000 0.5296 0.4704 0.0000
#
# Signalling fraction: 0.16407793688663186
# \model{strawberry}{apple}{sold}{eaten}{bought}{0.4577459692955017}{0.4179610311985016}{0.5295998454093933}
# ============================================================
# There is a strawberry and an apple. The _ is being chilled and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the other one is being chilled.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chilled, sold) 0.4496 0.0000 0.0000 0.5504
# (sold, eaten) 0.4577 0.0000 0.0000 0.5423
# (eaten, chilled) 0.0000 0.5031 0.4969 0.0000
#
# Signalling fraction: 0.10082250823121075
# \model{strawberry}{apple}{chilled}{sold}{eaten}{0.44958874583244324}{0.4577459692955017}{0.5030507445335388}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being eaten.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, sold) 0.4656 0.0000 0.0000 0.5344
# (sold, steamed) 0.5209 0.0000 0.0000 0.4791
# (steamed, eaten) 0.0000 0.4274 0.5726 0.0000
#
# Signalling fraction: 0.14529198406652433
# \model{strawberry}{apple}{eaten}{sold}{steamed}{0.46557754278182983}{0.5208516716957092}{0.42735400795936584}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being chilled.
# There is a strawberry and an apple. The _ is being chilled and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the other one is being eaten.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, chilled) 0.5627 0.0000 0.0000 0.4373
# (chilled, sold) 0.4496 0.0000 0.0000 0.5504
# (sold, eaten) 0.0000 0.4943 0.5057 0.0000
#
# Signalling fraction: 0.12543964336638014
# \model{strawberry}{apple}{eaten}{chilled}{sold}{0.5627198219299316}{0.44958874583244324}{0.4943127930164337}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being bought.
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the other one is being eaten.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, bought) 0.4180 0.0000 0.0000 0.5820
# (bought, sold) 0.4599 0.0000 0.0000 0.5401
# (sold, eaten) 0.0000 0.4943 0.5057 0.0000
#
# Signalling fraction: 0.1640779358416835
# \model{strawberry}{apple}{eaten}{bought}{sold}{0.4179610311985016}{0.45986413955688477}{0.4943127930164337}
# ============================================================
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the other one is being bought.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (bought, sold) 0.4599 0.0000 0.0000 0.5401
# (sold, eaten) 0.4577 0.0000 0.0000 0.5423
# (eaten, bought) 0.0000 0.4851 0.5149 0.0000
#
# Signalling fraction: 0.08450806046050574
# \model{strawberry}{apple}{bought}{sold}{eaten}{0.45986413955688477}{0.4577459692955017}{0.4851158857345581}
# ============================================================
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being bought.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bought, sold) 0.4599 0.0000 0.0000 0.5401
# (sold, steamed) 0.5209 0.0000 0.0000 0.4791
# (steamed, bought) 0.0000 0.4214 0.5786 0.0000
#
# Signalling fraction: 0.15728282926961645
# \model{strawberry}{apple}{bought}{sold}{steamed}{0.45986413955688477}{0.5208516716957092}{0.421358585357666}
# ============================================================
# Curent topic: (['dog', 'cat'], ['cleaned', 'bathed', 'chased', 'held', 'touched', 'fed', 'hunted', 'pet', 'watched'])
# Number of scenarios: 1008
# Processing 3024 sentences. Batching...
#   0%|          | 0/12 [00:00<?, ?it/s]
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, chased) 0.5580 0.0000 0.0000 0.4420
# (chased, cleaned) 0.0000 0.4675 0.5325 0.0000
#
# Signalling fraction: 0.11607819791791041
# \model{dog}{cat}{cleaned}{bathed}{chased}{0.47328394651412964}{0.558039128780365}{0.46753665804862976}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, cleaned) 0.0000 0.4422 0.5578 0.0000
#
# Signalling fraction: 0.11555653803998622
# \model{dog}{cat}{cleaned}{bathed}{held}{0.47328394651412964}{0.45406004786491394}{0.4422217309474945}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, cleaned) 0.0000 0.4481 0.5519 0.0000
#
# Signalling fraction: 0.15554964537937477
# \model{dog}{cat}{cleaned}{bathed}{touched}{0.47328394651412964}{0.4222251772880554}{0.4480821192264557}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, hunted) 0.5804 0.0000 0.0000 0.4196
# (hunted, cleaned) 0.0000 0.5567 0.4433 0.0000
#
# Signalling fraction: 0.16087973111389353
# \model{dog}{cat}{cleaned}{bathed}{hunted}{0.47328394651412964}{0.5804398059844971}{0.5567262768745422}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being pet.
# There is a dog and a cat. The _ is being pet and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, pet) 0.5450 0.0000 0.0000 0.4550
# (pet, cleaned) 0.0000 0.5394 0.4606 0.0000
#
# Signalling fraction: 0.09003323310429967
# \model{dog}{cat}{cleaned}{bathed}{pet}{0.47328394651412964}{0.5450166463851929}{0.5394042730331421}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, watched) 0.5371 0.0000 0.0000 0.4629
# (watched, cleaned) 0.0000 0.5434 0.4566 0.0000
#
# Signalling fraction: 0.08675646760983924
# \model{dog}{cat}{cleaned}{bathed}{watched}{0.47328394651412964}{0.537109911441803}{0.5433782339096069}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, chased) 0.5786 0.0000 0.0000 0.4214
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, cleaned) 0.0000 0.4422 0.5578 0.0000
#
# Signalling fraction: 0.1572372316467987
# \model{dog}{cat}{cleaned}{chased}{held}{0.5786186456680298}{0.5439749360084534}{0.4422217309474945}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, chased) 0.5786 0.0000 0.0000 0.4214
# (chased, hunted) 0.5677 0.0000 0.0000 0.4323
# (hunted, cleaned) 0.0000 0.5567 0.4433 0.0000
#
# Signalling fraction: 0.15723723162865333
# \model{dog}{cat}{cleaned}{chased}{hunted}{0.5786186456680298}{0.5676787495613098}{0.5567262768745422}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, cleaned) 0.0000 0.4481 0.5519 0.0000
#
# Signalling fraction: 0.13351356977688056
# \model{dog}{cat}{cleaned}{held}{touched}{0.5475002527236938}{0.4332432150840759}{0.4480821192264557}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, hunted) 0.4332 0.0000 0.0000 0.5668
# (hunted, cleaned) 0.0000 0.5567 0.4433 0.0000
#
# Signalling fraction: 0.13369524433807733
# \model{dog}{cat}{cleaned}{held}{hunted}{0.5475002527236938}{0.43315237760543823}{0.5567262768745422}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, watched) 0.5129 0.0000 0.0000 0.4871
# (watched, cleaned) 0.0000 0.5434 0.4566 0.0000
#
# Signalling fraction: 0.09500044501215243
# \model{dog}{cat}{cleaned}{held}{watched}{0.5475002527236938}{0.5129303932189941}{0.5433782339096069}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, cleaned) 0.0000 0.4675 0.5325 0.0000
#
# Signalling fraction: 0.09482562533210115
# \model{dog}{cat}{cleaned}{touched}{chased}{0.47516652941703796}{0.5474127531051636}{0.46753665804862976}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, held) 0.5463 0.0000 0.0000 0.4537
# (held, cleaned) 0.0000 0.4422 0.5578 0.0000
#
# Signalling fraction: 0.11555653766728313
# \model{dog}{cat}{cleaned}{touched}{held}{0.47516652941703796}{0.5462902784347534}{0.4422217309474945}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, hunted) 0.5573 0.0000 0.0000 0.4427
# (hunted, cleaned) 0.0000 0.5567 0.4433 0.0000
#
# Signalling fraction: 0.1145910015855216
# \model{dog}{cat}{cleaned}{touched}{hunted}{0.47516652941703796}{0.5572955012321472}{0.5567262768745422}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, watched) 0.5151 0.0000 0.0000 0.4849
# (watched, cleaned) 0.0000 0.5434 0.4566 0.0000
#
# Signalling fraction: 0.08675646662324499
# \model{dog}{cat}{cleaned}{touched}{watched}{0.47516652941703796}{0.5151239633560181}{0.5433782339096069}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, chased) 0.5786 0.0000 0.0000 0.4214
# (chased, bathed) 0.0000 0.5549 0.4451 0.0000
#
# Signalling fraction: 0.1572372309183172
# \model{dog}{cat}{bathed}{cleaned}{chased}{0.4228688180446625}{0.5786186456680298}{0.5549100041389465}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, bathed) 0.0000 0.4291 0.5709 0.0000
#
# Signalling fraction: 0.1542623638525542
# \model{dog}{cat}{bathed}{cleaned}{held}{0.4228688180446625}{0.5475002527236938}{0.4290807843208313}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being bathed.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, bathed) 0.0000 0.5189 0.4811 0.0000
#
# Signalling fraction: 0.15426236338995802
# \model{dog}{cat}{bathed}{cleaned}{touched}{0.4228688180446625}{0.47516652941703796}{0.5189061760902405}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, chased) 0.5580 0.0000 0.0000 0.4420
# (chased, cleaned) 0.4367 0.0000 0.0000 0.5633
# (cleaned, bathed) 0.0000 0.4398 0.5602 0.0000
#
# Signalling fraction: 0.1266409753746759
# \model{dog}{cat}{bathed}{chased}{cleaned}{0.558039128780365}{0.43667951226234436}{0.43981030583381653}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, chased) 0.5580 0.0000 0.0000 0.4420
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, bathed) 0.0000 0.4291 0.5709 0.0000
#
# Signalling fraction: 0.14183843127434725
# \model{dog}{cat}{bathed}{chased}{held}{0.558039128780365}{0.5439749360084534}{0.4290807843208313}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, bathed) 0.0000 0.4398 0.5602 0.0000
#
# Signalling fraction: 0.14367794942326695
# \model{dog}{cat}{bathed}{held}{cleaned}{0.45406004786491394}{0.42816102504730225}{0.43981030583381653}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, bathed) 0.0000 0.5189 0.4811 0.0000
#
# Signalling fraction: 0.13351356980643425
# \model{dog}{cat}{bathed}{held}{touched}{0.45406004786491394}{0.4332432150840759}{0.5189061760902405}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, cleaned) 0.4782 0.0000 0.0000 0.5218
# (cleaned, bathed) 0.0000 0.4398 0.5602 0.0000
#
# Signalling fraction: 0.15554964519380565
# \model{dog}{cat}{bathed}{touched}{cleaned}{0.4222251772880554}{0.4781704246997833}{0.43981030583381653}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, bathed) 0.0000 0.5549 0.4451 0.0000
#
# Signalling fraction: 0.15554964537695493
# \model{dog}{cat}{bathed}{touched}{chased}{0.4222251772880554}{0.5474127531051636}{0.5549100041389465}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, held) 0.5463 0.0000 0.0000 0.4537
# (held, bathed) 0.0000 0.4291 0.5709 0.0000
#
# Signalling fraction: 0.1555496453735099
# \model{dog}{cat}{bathed}{touched}{held}{0.4222251772880554}{0.5462902784347534}{0.4290807843208313}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, hunted) 0.5804 0.0000 0.0000 0.4196
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, bathed) 0.0000 0.4398 0.5602 0.0000
#
# Signalling fraction: 0.16087972971541253
# \model{dog}{cat}{bathed}{hunted}{cleaned}{0.5804398059844971}{0.5740037560462952}{0.43981030583381653}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, hunted) 0.5804 0.0000 0.0000 0.4196
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, bathed) 0.0000 0.4291 0.5709 0.0000
#
# Signalling fraction: 0.16087973057578908
# \model{dog}{cat}{bathed}{hunted}{held}{0.5804398059844971}{0.5743730664253235}{0.4290807843208313}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being pet.
# There is a dog and a cat. The _ is being pet and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, pet) 0.5450 0.0000 0.0000 0.4550
# (pet, cleaned) 0.4945 0.0000 0.0000 0.5055
# (cleaned, bathed) 0.0000 0.4398 0.5602 0.0000
#
# Signalling fraction: 0.12037938827695005
# \model{dog}{cat}{bathed}{pet}{cleaned}{0.5450166463851929}{0.4944732189178467}{0.43981030583381653}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4367 0.0000 0.0000 0.5633
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, chased) 0.0000 0.4628 0.5372 0.0000
#
# Signalling fraction: 0.1266409754047122
# \model{dog}{cat}{chased}{cleaned}{bathed}{0.43667951226234436}{0.47328394651412964}{0.46282583475112915}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4367 0.0000 0.0000 0.5633
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, chased) 0.0000 0.5548 0.4452 0.0000
#
# Signalling fraction: 0.1266409753538683
# \model{dog}{cat}{chased}{cleaned}{held}{0.43667951226234436}{0.5475002527236938}{0.5548053979873657}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4367 0.0000 0.0000 0.5633
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, chased) 0.0000 0.5047 0.4953 0.0000
#
# Signalling fraction: 0.12664097488672
# \model{dog}{cat}{chased}{cleaned}{touched}{0.43667951226234436}{0.47516652941703796}{0.5047338604927063}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5655 0.0000 0.0000 0.4345
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, chased) 0.0000 0.4380 0.5620 0.0000
#
# Signalling fraction: 0.15426236363155865
# \model{dog}{cat}{chased}{bathed}{cleaned}{0.5655115246772766}{0.4228688180446625}{0.4379636347293854}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5655 0.0000 0.0000 0.4345
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, chased) 0.0000 0.5548 0.4452 0.0000
#
# Signalling fraction: 0.13102298939892487
# \model{dog}{cat}{chased}{bathed}{held}{0.5655115246772766}{0.45406004786491394}{0.5548053979873657}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5655 0.0000 0.0000 0.4345
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, chased) 0.0000 0.5047 0.4953 0.0000
#
# Signalling fraction: 0.1555496444776473
# \model{dog}{cat}{chased}{bathed}{touched}{0.5655115246772766}{0.4222251772880554}{0.5047338604927063}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, chased) 0.0000 0.4380 0.5620 0.0000
#
# Signalling fraction: 0.14367794981273962
# \model{dog}{cat}{chased}{held}{cleaned}{0.5439749360084534}{0.42816102504730225}{0.4379636347293854}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, chased) 0.0000 0.4628 0.5372 0.0000
#
# Signalling fraction: 0.1536613702491051
# \model{dog}{cat}{chased}{held}{bathed}{0.5439749360084534}{0.4231693148612976}{0.46282583475112915}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, chased) 0.0000 0.5047 0.4953 0.0000
#
# Signalling fraction: 0.1335135697054467
# \model{dog}{cat}{chased}{held}{touched}{0.5439749360084534}{0.4332432150840759}{0.5047338604927063}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5677 0.0000 0.0000 0.4323
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, chased) 0.0000 0.4380 0.5620 0.0000
#
# Signalling fraction: 0.14800745237874313
# \model{dog}{cat}{chased}{hunted}{cleaned}{0.5676787495613098}{0.5740037560462952}{0.4379636347293854}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5677 0.0000 0.0000 0.4323
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, chased) 0.0000 0.4628 0.5372 0.0000
#
# Signalling fraction: 0.15972888455165501
# \model{dog}{cat}{chased}{hunted}{bathed}{0.5676787495613098}{0.5798644423484802}{0.46282583475112915}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5677 0.0000 0.0000 0.4323
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, chased) 0.0000 0.5548 0.4452 0.0000
#
# Signalling fraction: 0.14874619141472145
# \model{dog}{cat}{chased}{hunted}{held}{0.5676787495613098}{0.5743730664253235}{0.5548053979873657}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.14367794887004037
# \model{dog}{cat}{held}{cleaned}{bathed}{0.42816102504730225}{0.47328394651412964}{0.43290582299232483}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, chased) 0.5786 0.0000 0.0000 0.4214
# (chased, held) 0.0000 0.5820 0.4180 0.0000
#
# Signalling fraction: 0.16409319562993085
# \model{dog}{cat}{held}{cleaned}{chased}{0.42816102504730225}{0.5786186456680298}{0.5820465683937073}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being held.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, held) 0.0000 0.5624 0.4376 0.0000
#
# Signalling fraction: 0.14367794975670112
# \model{dog}{cat}{held}{cleaned}{touched}{0.42816102504730225}{0.47516652941703796}{0.5624086260795593}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.1542623628561549
# \model{dog}{cat}{held}{bathed}{cleaned}{0.4231693148612976}{0.4228688180446625}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, chased) 0.5580 0.0000 0.0000 0.4420
# (chased, held) 0.0000 0.5820 0.4180 0.0000
#
# Signalling fraction: 0.16409319637166586
# \model{dog}{cat}{held}{bathed}{chased}{0.4231693148612976}{0.558039128780365}{0.5820465683937073}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, held) 0.0000 0.5624 0.4376 0.0000
#
# Signalling fraction: 0.1555496436947803
# \model{dog}{cat}{held}{bathed}{touched}{0.4231693148612976}{0.4222251772880554}{0.5624086260795593}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, cleaned) 0.4782 0.0000 0.0000 0.5218
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.13351356954300397
# \model{dog}{cat}{held}{touched}{cleaned}{0.4332432150840759}{0.4781704246997833}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, bathed) 0.5345 0.0000 0.0000 0.4655
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.13418835371868887
# \model{dog}{cat}{held}{touched}{bathed}{0.4332432150840759}{0.5345175862312317}{0.43290582299232483}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, held) 0.0000 0.5820 0.4180 0.0000
#
# Signalling fraction: 0.16409319628520946
# \model{dog}{cat}{held}{touched}{chased}{0.4332432150840759}{0.5474127531051636}{0.5820465683937073}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, hunted) 0.4332 0.0000 0.0000 0.5668
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.14800745153352168
# \model{dog}{cat}{held}{hunted}{cleaned}{0.43315237760543823}{0.5740037560462952}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (held, hunted) 0.4332 0.0000 0.0000 0.5668
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.1597288846369771
# \model{dog}{cat}{held}{hunted}{bathed}{0.43315237760543823}{0.5798644423484802}{0.43290582299232483}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, cleaned) 0.4782 0.0000 0.0000 0.5218
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, touched) 0.0000 0.4372 0.5628 0.0000
#
# Signalling fraction: 0.12558090684727885
# \model{dog}{cat}{touched}{cleaned}{bathed}{0.4781704246997833}{0.47328394651412964}{0.4372095465660095}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, cleaned) 0.4782 0.0000 0.0000 0.5218
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, touched) 0.0000 0.5012 0.4988 0.0000
#
# Signalling fraction: 0.0950004457935516
# \model{dog}{cat}{touched}{cleaned}{held}{0.4781704246997833}{0.5475002527236938}{0.5012052059173584}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, bathed) 0.5345 0.0000 0.0000 0.4655
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, touched) 0.0000 0.4314 0.5686 0.0000
#
# Signalling fraction: 0.15426236351036804
# \model{dog}{cat}{touched}{bathed}{cleaned}{0.5345175862312317}{0.4228688180446625}{0.4313511848449707}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, bathed) 0.5345 0.0000 0.0000 0.4655
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, touched) 0.0000 0.5012 0.4988 0.0000
#
# Signalling fraction: 0.09187990400210455
# \model{dog}{cat}{touched}{bathed}{held}{0.5345175862312317}{0.45406004786491394}{0.5012052059173584}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, cleaned) 0.4367 0.0000 0.0000 0.5633
# (cleaned, touched) 0.0000 0.4314 0.5686 0.0000
#
# Signalling fraction: 0.13729762878176588
# \model{dog}{cat}{touched}{chased}{cleaned}{0.5474127531051636}{0.43667951226234436}{0.4313511848449707}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, bathed) 0.5655 0.0000 0.0000 0.4345
# (bathed, touched) 0.0000 0.4372 0.5628 0.0000
#
# Signalling fraction: 0.1310229893140673
# \model{dog}{cat}{touched}{chased}{bathed}{0.5474127531051636}{0.5655115246772766}{0.4372095465660095}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5474 0.0000 0.0000 0.4526
# (chased, held) 0.5440 0.0000 0.0000 0.4560
# (held, touched) 0.0000 0.5012 0.4988 0.0000
#
# Signalling fraction: 0.09482562525865579
# \model{dog}{cat}{touched}{chased}{held}{0.5474127531051636}{0.5439749360084534}{0.5012052059173584}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, held) 0.5463 0.0000 0.0000 0.4537
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, touched) 0.0000 0.4314 0.5686 0.0000
#
# Signalling fraction: 0.14367794926757393
# \model{dog}{cat}{touched}{held}{cleaned}{0.5462902784347534}{0.42816102504730225}{0.4313511848449707}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, held) 0.5463 0.0000 0.0000 0.4537
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, touched) 0.0000 0.4372 0.5628 0.0000
#
# Signalling fraction: 0.15366137019789494
# \model{dog}{cat}{touched}{held}{bathed}{0.5462902784347534}{0.4231693148612976}{0.4372095465660095}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5573 0.0000 0.0000 0.4427
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, touched) 0.0000 0.4314 0.5686 0.0000
#
# Signalling fraction: 0.14800745219498357
# \model{dog}{cat}{touched}{hunted}{cleaned}{0.5572955012321472}{0.5740037560462952}{0.4313511848449707}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5573 0.0000 0.0000 0.4427
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, touched) 0.0000 0.4372 0.5628 0.0000
#
# Signalling fraction: 0.15972888451503808
# \model{dog}{cat}{touched}{hunted}{bathed}{0.5572955012321472}{0.5798644423484802}{0.4372095465660095}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5573 0.0000 0.0000 0.4427
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, touched) 0.0000 0.5012 0.4988 0.0000
#
# Signalling fraction: 0.1487461923988448
# \model{dog}{cat}{touched}{hunted}{held}{0.5572955012321472}{0.5743730664253235}{0.5012052059173584}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, hunted) 0.0000 0.4855 0.5145 0.0000
#
# Signalling fraction: 0.14800745090273515
# \model{dog}{cat}{hunted}{cleaned}{bathed}{0.5740037560462952}{0.47328394651412964}{0.4854722321033478}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, chased) 0.5786 0.0000 0.0000 0.4214
# (chased, hunted) 0.0000 0.5674 0.4326 0.0000
#
# Signalling fraction: 0.15723723101107345
# \model{dog}{cat}{hunted}{cleaned}{chased}{0.5740037560462952}{0.5786186456680298}{0.5673589706420898}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, hunted) 0.0000 0.5135 0.4865 0.0000
#
# Signalling fraction: 0.1480074524520496
# \model{dog}{cat}{hunted}{cleaned}{held}{0.5740037560462952}{0.5475002527236938}{0.5134637951850891}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5740 0.0000 0.0000 0.4260
# (cleaned, touched) 0.4752 0.0000 0.0000 0.5248
# (touched, hunted) 0.0000 0.5149 0.4851 0.0000
#
# Signalling fraction: 0.14800745093632284
# \model{dog}{cat}{hunted}{cleaned}{touched}{0.5740037560462952}{0.47516652941703796}{0.5149024724960327}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, cleaned) 0.4229 0.0000 0.0000 0.5771
# (cleaned, hunted) 0.0000 0.5014 0.4986 0.0000
#
# Signalling fraction: 0.15972888464742063
# \model{dog}{cat}{hunted}{bathed}{cleaned}{0.5798644423484802}{0.4228688180446625}{0.501441240310669}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, chased) 0.5580 0.0000 0.0000 0.4420
# (chased, hunted) 0.0000 0.5674 0.4326 0.0000
#
# Signalling fraction: 0.15972888442456834
# \model{dog}{cat}{hunted}{bathed}{chased}{0.5798644423484802}{0.558039128780365}{0.5673589706420898}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, hunted) 0.0000 0.5135 0.4865 0.0000
#
# Signalling fraction: 0.1597288846706878
# \model{dog}{cat}{hunted}{bathed}{held}{0.5798644423484802}{0.45406004786491394}{0.5134637951850891}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5799 0.0000 0.0000 0.4201
# (bathed, touched) 0.4222 0.0000 0.0000 0.5778
# (touched, hunted) 0.0000 0.5149 0.4851 0.0000
#
# Signalling fraction: 0.15972888447847589
# \model{dog}{cat}{hunted}{bathed}{touched}{0.5798644423484802}{0.4222251772880554}{0.5149024724960327}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, cleaned) 0.4282 0.0000 0.0000 0.5718
# (cleaned, hunted) 0.0000 0.5014 0.4986 0.0000
#
# Signalling fraction: 0.14874619237041065
# \model{dog}{cat}{hunted}{held}{cleaned}{0.5743730664253235}{0.42816102504730225}{0.501441240310669}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, bathed) 0.4232 0.0000 0.0000 0.5768
# (bathed, hunted) 0.0000 0.4855 0.5145 0.0000
#
# Signalling fraction: 0.1536613702424492
# \model{dog}{cat}{hunted}{held}{bathed}{0.5743730664253235}{0.4231693148612976}{0.4854722321033478}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5744 0.0000 0.0000 0.4256
# (held, touched) 0.4332 0.0000 0.0000 0.5668
# (touched, hunted) 0.0000 0.5149 0.4851 0.0000
#
# Signalling fraction: 0.148746192416653
# \model{dog}{cat}{hunted}{held}{touched}{0.5743730664253235}{0.4332432150840759}{0.5149024724960327}
# ============================================================
# There is a dog and a cat. The _ is being pet and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being pet.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (pet, cleaned) 0.4945 0.0000 0.0000 0.5055
# (cleaned, bathed) 0.4733 0.0000 0.0000 0.5267
# (bathed, pet) 0.0000 0.5340 0.4660 0.0000
#
# Signalling fraction: 0.0679621096574613
# \model{dog}{cat}{pet}{cleaned}{bathed}{0.4944732189178467}{0.47328394651412964}{0.5339810848236084}
# ============================================================

# %%
df
# Out:
#                  nouns                                          modifiers  \
# 0  [strawberry, apple]  [rotten, sold, chilled, eaten, steamed, cooked...
# 1           [dog, cat]  [cleaned, bathed, chased, held, touched, fed, ...
#
#   models contextual_models
# 0    672                 9
# 1   1008                75

# %%
import matplotlib.pyplot as plt
print(f"total number of scenarios: {len(sfs_list)}.")
print(f"total number sheaf-contextual scenarios: {len(sheaf_models_list)}({len(sheaf_models_list)/len(sfs)*100:.2f}%).")
plt.hist(sfs, bins=24)

plt.xlim((0,1))
plt.title("Signalling fractions from language examples.")
plt.show()

freq, edge = np.histogram(sfs_list, range=(0, 1), bins=24)
out1 = ''
out2 = ''
for f, e in zip(freq, edge[:-1]):
    if e < 1/6-1e-5:
        out1 += f"({e:.4f}, {f}) "
    else:
        out2 += f"({e:.4f}, {f}) "
print(f'\\histogram{{{out1}}}{{{out2}}}')
# Out:
# total number of scenarios: 1680.
# total number sheaf-contextual scenarios: 84(8.33%).
# \histogram{(0.0000, 0) (0.0417, 1) (0.0833, 15) (0.1250, 68) }{(0.1667, 41) (0.2083, 65) (0.2500, 41) (0.2917, 63) (0.3333, 96) (0.3750, 125) (0.4167, 40) (0.4583, 86) (0.5000, 33) (0.5417, 83) (0.5833, 94) (0.6250, 111) (0.6667, 145) (0.7083, 108) (0.7500, 81) (0.7917, 108) (0.8333, 142) (0.8750, 122) (0.9167, 12) (0.9583, 0) }

# %%
# print(f"total number of scenarios: {len(cbds)}.")
# plt.hist(cbds, bins=50)

# plt.title("CbD from language examples.")
# plt.show()

# %%
# print(cbd_models[0])
# print(cbd_models[0].CbD_measure())

# %%
# from contextuality.model import random_pr_like_model
# random_sfs = []
# for i in range(n_scenario):
#     model = random_pr_like_model(3)
#     random_sfs.append(model.signalling_fraction())

# plt.hist(random_sfs, bins=50)
# plt.xlim((0,1))
# plt.title("Signalling fractions from random models")
# plt.show()
