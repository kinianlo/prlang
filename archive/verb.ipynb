# %% [markdown]
# <a href="https://colab.research.google.com/github/kinianlo/prlang/blob/main/archive/verb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PR-like models in langauge

# %% [markdown]
# ### Generate PR-like models with Masked LM

# %%
# !pip install numpy inflect torch transformers git+https://github.com/kinianlo/contextuality.git
# Out:
# Collecting git+https://github.com/kinianlo/contextuality.git
#   Cloning https://github.com/kinianlo/contextuality.git to /tmp/pip-req-build-8_9xxkq1
#   Running command git clone -q https://github.com/kinianlo/contextuality.git /tmp/pip-req-build-8_9xxkq1
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.19.2)
# Requirement already satisfied: picos in /usr/local/lib/python3.7/dist-packages (from Contextuality==0.0.1) (2.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from picos->Contextuality==0.0.1) (1.2.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)

# %%
import itertools
import numpy as np
import inflect
import random
import json
import pandas as pd
from tqdm.auto import tqdm
from time import time

from contextuality.model import Model, CyclicScenario

import torch
from transformers import AutoModelForMaskedLM, AutoTokenizer
from transformers import logging
logging.set_verbosity_error()

# %%
def get_probs(sentences_raw, options, model, tokenizer, mask_placeholder='_'):
    """
    Predict a masked word with probability scores for the provided options
    for the mask.
    
    Parameters
    ---------
    sentences_raw : str or (list of str)
    options : (list of str) or (list of (list of str))
    model : MaskedLM
    tokenizer : Tokenizer
    """
    torch.cuda.empty_cache()
    if type(sentences_raw) is str:
        sentences_raw = [sentences_raw]
    if type(options[0]) is str:
        options = [options for s in sentences_raw]
    
    partition_size = 2**8
    n_sentence = len(sentences_raw)
    if n_sentence > partition_size:
        print(f"Processing {n_sentence} sentences. Batching...")
        probs = []
        for i in tqdm(range(0, len(sentences_raw), partition_size)):
            sentences_raw_part = sentences_raw[i:i+partition_size]
            options_part = options[i:i+partition_size]
            probs += get_probs(sentences_raw_part, options_part, model,
                               tokenizer, mask_placeholder=mask_placeholder)
        return probs
        
    # Convert the option words into tokens
    options_token = [[tokenizer.tokenize(op)[0] for op in ops] for ops in options]
    options_id = [[tokenizer.vocab[op] for op in ops] for ops in options_token]
    
    # Replace mask placeholders with the mask token used by the given tokenizer
    sentences = [s.replace(mask_placeholder, tokenizer.mask_token) for s in sentences_raw]
    inputs = tokenizer(sentences, return_tensors='pt', padding=True).to(model.device)
    
    mask_indices = torch.where(inputs["input_ids"] == tokenizer.mask_token_id)
    
    outputs = model(**inputs)
    logits = outputs.logits
    
    mask_logits = logits[mask_indices]
    
    probs = [[] for i in range(len(sentences))]
    
    for i in range(len(mask_indices[0])):
        s_idx, m_idx = mask_indices[0][i], mask_indices[1][i]
        prob = torch.softmax(mask_logits[i][options_id[s_idx]], dim=-1).detach().cpu().numpy()
        prob = dict(zip(options[s_idx], prob))
        probs[s_idx] = prob
        
    if len(probs) == 1:
        probs = probs[0]
    return probs

# %%
# Initialise the language model and its tokenizer
device = "cuda:0" if torch.cuda.is_available() else "cpu"
lm_name = 'bert-base-uncased'
mlm = AutoModelForMaskedLM.from_pretrained(lm_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(lm_name)

# %% [markdown]
# ## The following handles a batch of examples
# Examples should be given in a text file where each row has the format:
#
# ```outcome1 outcome2: observable1 observable2 observable3 observable4 ...```
#
# For example,
#
# ```apple strawberry: sweet red round green big```
#
# For each row, all ordered combinations of 3 observables will be considered in the following.

# %%
def process_topics_file(file_name):
    topics = []
    with open(file_name) as file:
        for row in file:
            if not row.strip():
                continue
            outcomes = [] 
            observables = []
            outcomes_str, observables_str = map(str.strip, row.split(':'))
            outcomes = list(map(str.strip, set(outcomes_str.split(','))))
            observables = list(map(str.strip, set(observables_str.split(','))))
            topics.append((outcomes, observables))
    return topics

def process_schemas_file(file_name):
    schema_options = dict()
    schemas = dict()
    with open(file_name) as file:
        data = json.load(file)
        schema_options = data['options']
        schemas = data['schemas']
    return schema_options, schemas

# %%
def generate_scenarios(topics, schema=None):
    scenarios = []
    for topic in topics:
        outcomes, observables = topic
        out_perm = itertools.permutations(outcomes, 2)
        obs_perm = itertools.permutations(observables, 3)
        scenarios += list(itertools.product(out_perm, obs_perm))
    return scenarios

# %%
def a(word):
    """Return `a` or `an` depending on the given word.
    """
    return inflect.engine().a(word)

def generate_sentences(scenario, schema):
    sentences = []
    o, x = scenario
    if schema == 'adj':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is {x[0]} and the same one is {x[1]}.")
        sentences.append(f"{intro} The _ is {x[1]} and the same one is {x[2]}.")
        sentences.append(f"{intro} The _ is {x[2]} and the other one is {x[0]}.")
    elif schema == 'verb':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is being {x[0]} and the same one is being {x[1]}.")
        sentences.append(f"{intro} The _ is being {x[1]} and the same one is being {x[2]}.")
        sentences.append(f"{intro} The _ is being {x[2]} and the other one is being {x[0]}.")
    elif schema == 'prep':
        intro = f"There is {a(o[0])} and {a(o[1])}."
        sentences.append(f"{intro} The _ is {x[0]} and the same one is {x[1]}.")
        sentences.append(f"{intro} The _ is {x[1]} and the same one is {x[2]}.")
        sentences.append(f"{intro} The _ is {x[2]} and the other one is {x[0]}.")
    return sentences

def get_mask_options(scenario, schema):
    o, x = scenario
    return [o for i in range(3)]

# %% [markdown]
# # Load topics files here!

# %%
# %cd
# %rm -rf prlang
# !git clone https://github.com/kinianlo/prlang.git
# %cd prlang
# Out:
# /root
# Cloning into 'prlang'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 105 (delta 52), reused 56 (delta 19), pack-reused 0
# Receiving objects: 100% (105/105), 177.98 KiB | 7.74 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /root/prlang

# %%
topics = process_topics_file('data/verb.txt')
schema = 'verb'

print(f'Topics for schema `{schema}`:')
for t in topics:
    print(t)
# Out:
# Topics for schema `verb`:
# (['apple', 'strawberry'], ['rotten', 'chilled', 'sold', 'washed', 'eaten', 'steamed', 'cooked', 'bought'])
# (['dog', 'cat'], ['watched', 'chased', 'hunted', 'held', 'touched', 'bathed', 'cleaned', 'pet', 'fed'])

# %%
df = pd.DataFrame(columns=['nouns', 'modifiers', 'models', 'contextual_models'])

sfs_list = []
sheaf_models_list = []

for topic in topics:
    row = dict()
    scenarios = generate_scenarios([topic], schema)
    print(f"Curent topic: {topic}")
    row['nouns'], row['modifiers'] = topic

    n_scenario = len(scenarios)
    row['models'] = n_scenario
    print(f"Number of scenarios: {n_scenario}")
    
    sentences = [generate_sentences(scen, schema) for scen in scenarios]
    sentences_flat = list(itertools.chain.from_iterable(sentences))

    mask_options = [get_mask_options(scen, schema) for scen in scenarios]
    mask_options_flat = list(itertools.chain.from_iterable(mask_options))

    probs_flat = get_probs(sentences_flat, mask_options_flat, mlm, tokenizer)
    probs = [probs_flat[3*i:3*i+3] for i in range(n_scenario)]

    sheaf_models = []
    cbd_models = []
    sfs = []
    cbds = []
    for i in range(n_scenario):
        outcomes, observables = scenarios[i]
        tri_scenario = CyclicScenario(observables, 2)
        o0, o1 = outcomes
        x0, x1, x2 = observables
        
        table = []
        table.append([probs[i][0][o0], 0, 0, probs[i][0][o1]])
        table.append([probs[i][1][o0], 0, 0, probs[i][1][o1]])
        table.append([0, probs[i][2][o0], probs[i][2][o1], 0])
        
        model = Model(tri_scenario, table)
        sfs.append(model.signalling_fraction())
        cbds.append(model.CbD_measure())
        if sfs[-1] < 1/6:
            sheaf_models.append(model)
            for s in sentences[i]:
                print(s)
            print(model)
            print(f"Signalling fraction: {model.signalling_fraction()}")
            print(f"\\model{{{o0}}}{{{o1}}}{{{x0}}}{{{x1}}}{{{x2}}}{{{probs[i][0][o0]}}}{{{probs[i][1][o0]}}}{{{probs[i][2][o0]}}}")
            print('='*60)
        
        if cbds[-1] > 0:
            cbd_models.append(model)
    sheaf_models_list += sheaf_models
    sfs_list += sfs
    row['contextual_models'] = len(sheaf_models)
    df = df.append(row, ignore_index=True)
# Out:
# Curent topic: (['apple', 'strawberry'], ['rotten', 'chilled', 'sold', 'washed', 'eaten', 'steamed', 'cooked', 'bought'])
# Number of scenarios: 672
# Processing 2016 sentences. Batching...
#   0%|          | 0/8 [00:00<?, ?it/s]
# There is a strawberry and an apple. The _ is being chilled and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the other one is being chilled.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chilled, sold) 0.4494 0.0000 0.0000 0.5506
# (sold, eaten) 0.4587 0.0000 0.0000 0.5413
# (eaten, chilled) 0.0000 0.5026 0.4974 0.0000
#
# Signalling fraction: 0.10127323859915083
# \model{strawberry}{apple}{chilled}{sold}{eaten}{0.4493633806705475}{0.45867520570755005}{0.5025741457939148}
# ============================================================
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being chilled.
# There is a strawberry and an apple. The _ is being chilled and the other one is being sold.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4587 0.0000 0.0000 0.5413
# (eaten, chilled) 0.5621 0.0000 0.0000 0.4379
# (chilled, sold) 0.0000 0.4416 0.5584 0.0000
#
# Signalling fraction: 0.12420093883186689
# \model{strawberry}{apple}{sold}{eaten}{chilled}{0.45867520570755005}{0.5621004104614258}{0.4415716826915741}
# ============================================================
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being sold.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4587 0.0000 0.0000 0.5413
# (eaten, steamed) 0.5773 0.0000 0.0000 0.4227
# (steamed, sold) 0.0000 0.4295 0.5705 0.0000
#
# Signalling fraction: 0.15464866155424972
# \model{strawberry}{apple}{sold}{eaten}{steamed}{0.45867520570755005}{0.5773243308067322}{0.42952868342399597}
# ============================================================
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the same one is being bought.
# There is a strawberry and an apple. The _ is being bought and the other one is being sold.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (sold, eaten) 0.4587 0.0000 0.0000 0.5413
# (eaten, bought) 0.4171 0.0000 0.0000 0.5829
# (bought, sold) 0.0000 0.5295 0.4705 0.0000
#
# Signalling fraction: 0.16579598114074257
# \model{strawberry}{apple}{sold}{eaten}{bought}{0.45867520570755005}{0.41710200905799866}{0.5295428037643433}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being chilled.
# There is a strawberry and an apple. The _ is being chilled and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the other one is being eaten.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, chilled) 0.5621 0.0000 0.0000 0.4379
# (chilled, sold) 0.4494 0.0000 0.0000 0.5506
# (sold, eaten) 0.0000 0.4938 0.5062 0.0000
#
# Signalling fraction: 0.12420093961470124
# \model{strawberry}{apple}{eaten}{chilled}{sold}{0.5621004104614258}{0.4493633806705475}{0.49377113580703735}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being eaten.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, sold) 0.4655 0.0000 0.0000 0.5345
# (sold, steamed) 0.5205 0.0000 0.0000 0.4795
# (steamed, eaten) 0.0000 0.4270 0.5730 0.0000
#
# Signalling fraction: 0.1459770798534319
# \model{strawberry}{apple}{eaten}{sold}{steamed}{0.4655263125896454}{0.5205491781234741}{0.4270114600658417}
# ============================================================
# There is a strawberry and an apple. The _ is being eaten and the same one is being bought.
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the other one is being eaten.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (eaten, bought) 0.4171 0.0000 0.0000 0.5829
# (bought, sold) 0.4592 0.0000 0.0000 0.5408
# (sold, eaten) 0.0000 0.4938 0.5062 0.0000
#
# Signalling fraction: 0.1657959800398593
# \model{strawberry}{apple}{eaten}{bought}{sold}{0.41710200905799866}{0.4591696560382843}{0.49377113580703735}
# ============================================================
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being eaten.
# There is a strawberry and an apple. The _ is being eaten and the other one is being bought.
#                 (0, 0) (0, 1) (1, 0) (1, 1)
# (bought, sold) 0.4592 0.0000 0.0000 0.5408
# (sold, eaten) 0.4587 0.0000 0.0000 0.5413
# (eaten, bought) 0.0000 0.4847 0.5153 0.0000
#
# Signalling fraction: 0.08265006478176684
# \model{strawberry}{apple}{bought}{sold}{eaten}{0.45916733145713806}{0.45867496728897095}{0.4846947491168976}
# ============================================================
# There is a strawberry and an apple. The _ is being bought and the same one is being sold.
# There is a strawberry and an apple. The _ is being sold and the same one is being steamed.
# There is a strawberry and an apple. The _ is being steamed and the other one is being bought.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bought, sold) 0.4592 0.0000 0.0000 0.5408
# (sold, steamed) 0.5206 0.0000 0.0000 0.4794
# (steamed, bought) 0.0000 0.4204 0.5796 0.0000
#
# Signalling fraction: 0.15921586750399208
# \model{strawberry}{apple}{bought}{sold}{steamed}{0.45916733145713806}{0.5205503702163696}{0.42039206624031067}
# ============================================================
# Curent topic: (['dog', 'cat'], ['watched', 'chased', 'hunted', 'held', 'touched', 'bathed', 'cleaned', 'pet', 'fed'])
# Number of scenarios: 1008
# Processing 3024 sentences. Batching...
#   0%|          | 0/12 [00:00<?, ?it/s]
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5678 0.0000 0.0000 0.4322
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, chased) 0.0000 0.5552 0.4448 0.0000
#
# Signalling fraction: 0.14790439495519603
# \model{dog}{cat}{chased}{hunted}{held}{0.5678436756134033}{0.5739522576332092}{0.5552383661270142}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5678 0.0000 0.0000 0.4322
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, chased) 0.0000 0.4630 0.5370 0.0000
#
# Signalling fraction: 0.15846008046779048
# \model{dog}{cat}{chased}{hunted}{bathed}{0.5678436756134033}{0.579230010509491}{0.4629870653152466}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, hunted) 0.5678 0.0000 0.0000 0.4322
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, chased) 0.0000 0.4382 0.5618 0.0000
#
# Signalling fraction: 0.14831906546128049
# \model{dog}{cat}{chased}{hunted}{cleaned}{0.5678436756134033}{0.5741595029830933}{0.43817421793937683}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, chased) 0.0000 0.5045 0.4955 0.0000
#
# Signalling fraction: 0.1329051254822189
# \model{dog}{cat}{chased}{held}{touched}{0.5443408489227295}{0.4335474371910095}{0.5045262575149536}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, chased) 0.0000 0.4630 0.5370 0.0000
#
# Signalling fraction: 0.15321850773460655
# \model{dog}{cat}{chased}{held}{bathed}{0.5443408489227295}{0.4233907461166382}{0.4629870653152466}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, chased) 0.0000 0.4382 0.5618 0.0000
#
# Signalling fraction: 0.1437227725082867
# \model{dog}{cat}{chased}{held}{cleaned}{0.5443408489227295}{0.4281386137008667}{0.43817421793937683}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5651 0.0000 0.0000 0.4349
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, chased) 0.0000 0.5552 0.4448 0.0000
#
# Signalling fraction: 0.130244016198378
# \model{dog}{cat}{chased}{bathed}{held}{0.5651220083236694}{0.45408228039741516}{0.5552383661270142}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5651 0.0000 0.0000 0.4349
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, chased) 0.0000 0.5045 0.4955 0.0000
#
# Signalling fraction: 0.1554961195472061
# \model{dog}{cat}{chased}{bathed}{touched}{0.5651220083236694}{0.42225193977355957}{0.5045262575149536}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, bathed) 0.5651 0.0000 0.0000 0.4349
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, chased) 0.0000 0.4382 0.5618 0.0000
#
# Signalling fraction: 0.15397787066947743
# \model{dog}{cat}{chased}{bathed}{cleaned}{0.5651220083236694}{0.42301106452941895}{0.43817421793937683}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4366 0.0000 0.0000 0.5634
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, chased) 0.0000 0.5552 0.4448 0.0000
#
# Signalling fraction: 0.12685304867486236
# \model{dog}{cat}{chased}{cleaned}{held}{0.43657347559928894}{0.5475032925605774}{0.5552383661270142}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being chased.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4366 0.0000 0.0000 0.5634
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, chased) 0.0000 0.5045 0.4955 0.0000
#
# Signalling fraction: 0.1268530482022172
# \model{dog}{cat}{chased}{cleaned}{touched}{0.43657347559928894}{0.4746832549571991}{0.5045262575149536}
# ============================================================
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being chased.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (chased, cleaned) 0.4366 0.0000 0.0000 0.5634
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, chased) 0.0000 0.4630 0.5370 0.0000
#
# Signalling fraction: 0.1268530487322197
# \model{dog}{cat}{chased}{cleaned}{bathed}{0.43657347559928894}{0.4733973741531372}{0.4629870653152466}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, hunted) 0.0000 0.5142 0.4858 0.0000
#
# Signalling fraction: 0.14790439601916217
# \model{dog}{cat}{hunted}{held}{touched}{0.5739522576332092}{0.4335474371910095}{0.5141637325286865}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, hunted) 0.0000 0.4866 0.5134 0.0000
#
# Signalling fraction: 0.1532185077408873
# \model{dog}{cat}{hunted}{held}{bathed}{0.5739522576332092}{0.4233907461166382}{0.4865983724594116}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, hunted) 0.0000 0.5015 0.4985 0.0000
#
# Signalling fraction: 0.1479043959228602
# \model{dog}{cat}{hunted}{held}{cleaned}{0.5739522576332092}{0.4281386137008667}{0.5014832019805908}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, chased) 0.5579 0.0000 0.0000 0.4421
# (chased, hunted) 0.0000 0.5673 0.4327 0.0000
#
# Signalling fraction: 0.15846008034640036
# \model{dog}{cat}{hunted}{bathed}{chased}{0.579230010509491}{0.5578827261924744}{0.5672798156738281}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being hunted.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, hunted) 0.0000 0.5136 0.4864 0.0000
#
# Signalling fraction: 0.15846008059038585
# \model{dog}{cat}{hunted}{bathed}{held}{0.579230010509491}{0.45408228039741516}{0.5136182308197021}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, hunted) 0.0000 0.5142 0.4858 0.0000
#
# Signalling fraction: 0.15846008028745717
# \model{dog}{cat}{hunted}{bathed}{touched}{0.579230010509491}{0.42225193977355957}{0.5141637325286865}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, hunted) 0.0000 0.5015 0.4985 0.0000
#
# Signalling fraction: 0.15846008051393456
# \model{dog}{cat}{hunted}{bathed}{cleaned}{0.579230010509491}{0.42301106452941895}{0.5014832019805908}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, chased) 0.5788 0.0000 0.0000 0.4212
# (chased, hunted) 0.0000 0.5673 0.4327 0.0000
#
# Signalling fraction: 0.15763068125200475
# \model{dog}{cat}{hunted}{cleaned}{chased}{0.5741595029830933}{0.5788153409957886}{0.5672798156738281}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, hunted) 0.0000 0.5136 0.4864 0.0000
#
# Signalling fraction: 0.14831906553535357
# \model{dog}{cat}{hunted}{cleaned}{held}{0.5741595029830933}{0.5475032925605774}{0.5136182308197021}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being hunted.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, hunted) 0.0000 0.5142 0.4858 0.0000
#
# Signalling fraction: 0.1483190640059303
# \model{dog}{cat}{hunted}{cleaned}{touched}{0.5741595029830933}{0.4746832549571991}{0.5141637325286865}
# ============================================================
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being hunted.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, hunted) 0.0000 0.4866 0.5134 0.0000
#
# Signalling fraction: 0.14831906399915662
# \model{dog}{cat}{hunted}{cleaned}{bathed}{0.5741595029830933}{0.4733973741531372}{0.4865983724594116}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (held, hunted) 0.4339 0.0000 0.0000 0.5661
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.15846008050520244
# \model{dog}{cat}{held}{hunted}{bathed}{0.4338859021663666}{0.579230010509491}{0.43286392092704773}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, hunted) 0.4339 0.0000 0.0000 0.5661
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.1483190649758802
# \model{dog}{cat}{held}{hunted}{cleaned}{0.4338859021663666}{0.5741595029830933}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, held) 0.0000 0.5826 0.4174 0.0000
#
# Signalling fraction: 0.1651402115168823
# \model{dog}{cat}{held}{touched}{chased}{0.4335474371910095}{0.5465668439865112}{0.5825701355934143}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, bathed) 0.5337 0.0000 0.0000 0.4663
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.13427215763123224
# \model{dog}{cat}{held}{touched}{bathed}{0.4335474371910095}{0.5337252020835876}{0.43286392092704773}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, cleaned) 0.4780 0.0000 0.0000 0.5220
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.13290512533911358
# \model{dog}{cat}{held}{touched}{cleaned}{0.4335474371910095}{0.4780048429965973}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, chased) 0.5579 0.0000 0.0000 0.4421
# (chased, held) 0.0000 0.5826 0.4174 0.0000
#
# Signalling fraction: 0.16514021156029413
# \model{dog}{cat}{held}{bathed}{chased}{0.4233907461166382}{0.5578827261924744}{0.5825701355934143}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, held) 0.0000 0.5625 0.4375 0.0000
#
# Signalling fraction: 0.15549611913460115
# \model{dog}{cat}{held}{bathed}{touched}{0.4233907461166382}{0.42225193977355957}{0.5625292658805847}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, held) 0.0000 0.5248 0.4752 0.0000
#
# Signalling fraction: 0.15397787049818712
# \model{dog}{cat}{held}{bathed}{cleaned}{0.4233907461166382}{0.42301106452941895}{0.5248218178749084}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, chased) 0.5788 0.0000 0.0000 0.4212
# (chased, held) 0.0000 0.5826 0.4174 0.0000
#
# Signalling fraction: 0.16514021069681772
# \model{dog}{cat}{held}{cleaned}{chased}{0.4281386137008667}{0.5788153409957886}{0.5825701355934143}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being held.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, held) 0.0000 0.5625 0.4375 0.0000
#
# Signalling fraction: 0.14372277244290887
# \model{dog}{cat}{held}{cleaned}{touched}{0.4281386137008667}{0.4746832549571991}{0.5625292658805847}
# ============================================================
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being held.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, held) 0.0000 0.4329 0.5671 0.0000
#
# Signalling fraction: 0.14372277156641344
# \model{dog}{cat}{held}{cleaned}{bathed}{0.4281386137008667}{0.4733973741531372}{0.43286392092704773}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, touched) 0.0000 0.5008 0.4992 0.0000
#
# Signalling fraction: 0.09313356824604413
# \model{dog}{cat}{touched}{chased}{held}{0.5465668439865112}{0.5443408489227295}{0.5007624626159668}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, bathed) 0.5651 0.0000 0.0000 0.4349
# (bathed, touched) 0.0000 0.4375 0.5625 0.0000
#
# Signalling fraction: 0.13024401613190795
# \model{dog}{cat}{touched}{chased}{bathed}{0.5465668439865112}{0.5651220083236694}{0.43747377395629883}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, cleaned) 0.4366 0.0000 0.0000 0.5634
# (cleaned, touched) 0.0000 0.4315 0.5685 0.0000
#
# Signalling fraction: 0.13709133712912447
# \model{dog}{cat}{touched}{chased}{cleaned}{0.5465668439865112}{0.43657347559928894}{0.4314543306827545}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5570 0.0000 0.0000 0.4430
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, touched) 0.0000 0.5008 0.4992 0.0000
#
# Signalling fraction: 0.14790439599958882
# \model{dog}{cat}{touched}{hunted}{held}{0.556964635848999}{0.5739522576332092}{0.5007624626159668}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5570 0.0000 0.0000 0.4430
# (hunted, bathed) 0.5792 0.0000 0.0000 0.4208
# (bathed, touched) 0.0000 0.4375 0.5625 0.0000
#
# Signalling fraction: 0.15846008043733784
# \model{dog}{cat}{touched}{hunted}{bathed}{0.556964635848999}{0.579230010509491}{0.43747377395629883}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, hunted) 0.5570 0.0000 0.0000 0.4430
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, touched) 0.0000 0.4315 0.5685 0.0000
#
# Signalling fraction: 0.14831906526915717
# \model{dog}{cat}{touched}{hunted}{cleaned}{0.556964635848999}{0.5741595029830933}{0.4314543306827545}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, held) 0.5456 0.0000 0.0000 0.4544
# (held, bathed) 0.4234 0.0000 0.0000 0.5766
# (bathed, touched) 0.0000 0.4375 0.5625 0.0000
#
# Signalling fraction: 0.15321850768857714
# \model{dog}{cat}{touched}{held}{bathed}{0.5456136465072632}{0.4233907461166382}{0.43747377395629883}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, held) 0.5456 0.0000 0.0000 0.4544
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, touched) 0.0000 0.4315 0.5685 0.0000
#
# Signalling fraction: 0.14372277200696426
# \model{dog}{cat}{touched}{held}{cleaned}{0.5456136465072632}{0.4281386137008667}{0.4314543306827545}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, bathed) 0.5337 0.0000 0.0000 0.4663
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, touched) 0.0000 0.5008 0.4992 0.0000
#
# Signalling fraction: 0.0918354389738063
# \model{dog}{cat}{touched}{bathed}{held}{0.5337252020835876}{0.45408228039741516}{0.5007624626159668}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, bathed) 0.5337 0.0000 0.0000 0.4663
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, touched) 0.0000 0.4315 0.5685 0.0000
#
# Signalling fraction: 0.15397787054274337
# \model{dog}{cat}{touched}{bathed}{cleaned}{0.5337252020835876}{0.42301106452941895}{0.4314543306827545}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, cleaned) 0.4780 0.0000 0.0000 0.5220
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, touched) 0.0000 0.5008 0.4992 0.0000
#
# Signalling fraction: 0.09500652546660315
# \model{dog}{cat}{touched}{cleaned}{held}{0.4780048429965973}{0.5475032925605774}{0.5007624626159668}
# ============================================================
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being touched.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (touched, cleaned) 0.4780 0.0000 0.0000 0.5220
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, touched) 0.0000 0.4375 0.5625 0.0000
#
# Signalling fraction: 0.12505245206652826
# \model{dog}{cat}{touched}{cleaned}{bathed}{0.4780048429965973}{0.4733973741531372}{0.43747377395629883}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, chased) 0.5579 0.0000 0.0000 0.4421
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, bathed) 0.0000 0.4287 0.5713 0.0000
#
# Signalling fraction: 0.14259344331088397
# \model{dog}{cat}{bathed}{chased}{held}{0.5578827261924744}{0.5443408489227295}{0.42870327830314636}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, chased) 0.5579 0.0000 0.0000 0.4421
# (chased, cleaned) 0.4366 0.0000 0.0000 0.5634
# (cleaned, bathed) 0.0000 0.4414 0.5586 0.0000
#
# Signalling fraction: 0.12685304873616432
# \model{dog}{cat}{bathed}{chased}{cleaned}{0.5578827261924744}{0.43657347559928894}{0.4414089620113373}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                  (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, hunted) 0.5807 0.0000 0.0000 0.4193
# (hunted, held) 0.5740 0.0000 0.0000 0.4260
# (held, bathed) 0.0000 0.4287 0.5713 0.0000
#
# Signalling fraction: 0.161417483722044
# \model{dog}{cat}{bathed}{hunted}{held}{0.5807087421417236}{0.5739522576332092}{0.42870327830314636}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, hunted) 0.5807 0.0000 0.0000 0.4193
# (hunted, cleaned) 0.5742 0.0000 0.0000 0.4258
# (cleaned, bathed) 0.0000 0.4414 0.5586 0.0000
#
# Signalling fraction: 0.161417482535116
# \model{dog}{cat}{bathed}{hunted}{cleaned}{0.5807087421417236}{0.5741595029830933}{0.4414089620113373}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, bathed) 0.0000 0.5184 0.4816 0.0000
#
# Signalling fraction: 0.13290512559239143
# \model{dog}{cat}{bathed}{held}{touched}{0.45408228039741516}{0.4335474371910095}{0.5184195041656494}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, cleaned) 0.4281 0.0000 0.0000 0.5719
# (cleaned, bathed) 0.0000 0.4414 0.5586 0.0000
#
# Signalling fraction: 0.14372277232136277
# \model{dog}{cat}{bathed}{held}{cleaned}{0.45408228039741516}{0.4281386137008667}{0.4414089620113373}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, bathed) 0.0000 0.5559 0.4441 0.0000
#
# Signalling fraction: 0.15549612040646532
# \model{dog}{cat}{bathed}{touched}{chased}{0.42225193977355957}{0.5465668439865112}{0.5559369921684265}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, held) 0.5456 0.0000 0.0000 0.4544
# (held, bathed) 0.0000 0.4287 0.5713 0.0000
#
# Signalling fraction: 0.15549612039173322
# \model{dog}{cat}{bathed}{touched}{held}{0.42225193977355957}{0.5456136465072632}{0.42870327830314636}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, cleaned) 0.4780 0.0000 0.0000 0.5220
# (cleaned, bathed) 0.0000 0.4414 0.5586 0.0000
#
# Signalling fraction: 0.15549612026380344
# \model{dog}{cat}{bathed}{touched}{cleaned}{0.42225193977355957}{0.4780048429965973}{0.4414089620113373}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, chased) 0.5788 0.0000 0.0000 0.4212
# (chased, bathed) 0.0000 0.5559 0.4441 0.0000
#
# Signalling fraction: 0.15763068137997527
# \model{dog}{cat}{bathed}{cleaned}{chased}{0.42301106452941895}{0.5788153409957886}{0.5559369921684265}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, bathed) 0.0000 0.4287 0.5713 0.0000
#
# Signalling fraction: 0.15397787087938353
# \model{dog}{cat}{bathed}{cleaned}{held}{0.42301106452941895}{0.5475032925605774}{0.42870327830314636}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being bathed.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, cleaned) 0.4230 0.0000 0.0000 0.5770
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, bathed) 0.0000 0.5184 0.4816 0.0000
#
# Signalling fraction: 0.1539778704000152
# \model{dog}{cat}{bathed}{cleaned}{touched}{0.42301106452941895}{0.4746832549571991}{0.5184195041656494}
# ============================================================
# There is a dog and a cat. The _ is being bathed and the same one is being pet.
# There is a dog and a cat. The _ is being pet and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the other one is being bathed.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (bathed, pet) 0.5453 0.0000 0.0000 0.4547
# (pet, cleaned) 0.4938 0.0000 0.0000 0.5062
# (cleaned, bathed) 0.0000 0.4414 0.5586 0.0000
#
# Signalling fraction: 0.11718207591855923
# \model{dog}{cat}{bathed}{pet}{cleaned}{0.5453259348869324}{0.49380001425743103}{0.4414089620113373}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, chased) 0.5788 0.0000 0.0000 0.4212
# (chased, hunted) 0.5678 0.0000 0.0000 0.4322
# (hunted, cleaned) 0.0000 0.5570 0.4430 0.0000
#
# Signalling fraction: 0.15763068188854146
# \model{dog}{cat}{cleaned}{chased}{hunted}{0.5788153409957886}{0.5678436756134033}{0.5569982528686523}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, chased) 0.5788 0.0000 0.0000 0.4212
# (chased, held) 0.5443 0.0000 0.0000 0.4557
# (held, cleaned) 0.0000 0.4426 0.5574 0.0000
#
# Signalling fraction: 0.15763068191287422
# \model{dog}{cat}{cleaned}{chased}{held}{0.5788153409957886}{0.5443408489227295}{0.44260498881340027}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, watched) 0.5127 0.0000 0.0000 0.4873
# (watched, cleaned) 0.0000 0.5438 0.4562 0.0000
#
# Signalling fraction: 0.09500652434417156
# \model{dog}{cat}{cleaned}{held}{watched}{0.5475032925605774}{0.5127192735671997}{0.5437655448913574}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, hunted) 0.4339 0.0000 0.0000 0.5661
# (hunted, cleaned) 0.0000 0.5570 0.4430 0.0000
#
# Signalling fraction: 0.1322281951017732
# \model{dog}{cat}{cleaned}{held}{hunted}{0.5475032925605774}{0.4338859021663666}{0.5569982528686523}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being held.
# There is a dog and a cat. The _ is being held and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, held) 0.5475 0.0000 0.0000 0.4525
# (held, touched) 0.4335 0.0000 0.0000 0.5665
# (touched, cleaned) 0.0000 0.4478 0.5522 0.0000
#
# Signalling fraction: 0.13290512556141576
# \model{dog}{cat}{cleaned}{held}{touched}{0.5475032925605774}{0.4335474371910095}{0.4478059709072113}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, watched) 0.5155 0.0000 0.0000 0.4845
# (watched, cleaned) 0.0000 0.5438 0.4562 0.0000
#
# Signalling fraction: 0.08753108849097868
# \model{dog}{cat}{cleaned}{touched}{watched}{0.4746832549571991}{0.5154657959938049}{0.5437655448913574}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, chased) 0.5466 0.0000 0.0000 0.4534
# (chased, cleaned) 0.0000 0.4675 0.5325 0.0000
#
# Signalling fraction: 0.09313356866916123
# \model{dog}{cat}{cleaned}{touched}{chased}{0.4746832549571991}{0.5465668439865112}{0.4675427973270416}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, hunted) 0.5570 0.0000 0.0000 0.4430
# (hunted, cleaned) 0.0000 0.5570 0.4430 0.0000
#
# Signalling fraction: 0.11399662491355556
# \model{dog}{cat}{cleaned}{touched}{hunted}{0.4746832549571991}{0.556964635848999}{0.5569982528686523}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, touched) 0.4747 0.0000 0.0000 0.5253
# (touched, held) 0.5456 0.0000 0.0000 0.4544
# (held, cleaned) 0.0000 0.4426 0.5574 0.0000
#
# Signalling fraction: 0.1147900219598732
# \model{dog}{cat}{cleaned}{touched}{held}{0.4746832549571991}{0.5456136465072632}{0.44260498881340027}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being watched.
# There is a dog and a cat. The _ is being watched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, watched) 0.5370 0.0000 0.0000 0.4630
# (watched, cleaned) 0.0000 0.5438 0.4562 0.0000
#
# Signalling fraction: 0.08753108955042432
# \model{dog}{cat}{cleaned}{bathed}{watched}{0.4733973741531372}{0.5370359420776367}{0.5437655448913574}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being chased.
# There is a dog and a cat. The _ is being chased and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, chased) 0.5579 0.0000 0.0000 0.4421
# (chased, cleaned) 0.0000 0.4675 0.5325 0.0000
#
# Signalling fraction: 0.11576539274104769
# \model{dog}{cat}{cleaned}{bathed}{chased}{0.4733973741531372}{0.5578827261924744}{0.4675427973270416}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being hunted.
# There is a dog and a cat. The _ is being hunted and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, hunted) 0.5807 0.0000 0.0000 0.4193
# (hunted, cleaned) 0.0000 0.5570 0.4430 0.0000
#
# Signalling fraction: 0.1614174842170839
# \model{dog}{cat}{cleaned}{bathed}{hunted}{0.4733973741531372}{0.5807087421417236}{0.5569982528686523}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being held.
# There is a dog and a cat. The _ is being held and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, held) 0.4541 0.0000 0.0000 0.5459
# (held, cleaned) 0.0000 0.4426 0.5574 0.0000
#
# Signalling fraction: 0.11479002230793711
# \model{dog}{cat}{cleaned}{bathed}{held}{0.4733973741531372}{0.45408228039741516}{0.44260498881340027}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being touched.
# There is a dog and a cat. The _ is being touched and the other one is being cleaned.
#                    (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, touched) 0.4223 0.0000 0.0000 0.5777
# (touched, cleaned) 0.0000 0.4478 0.5522 0.0000
#
# Signalling fraction: 0.15549612040711736
# \model{dog}{cat}{cleaned}{bathed}{touched}{0.4733973741531372}{0.42225193977355957}{0.4478059709072113}
# ============================================================
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the same one is being pet.
# There is a dog and a cat. The _ is being pet and the other one is being cleaned.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, pet) 0.5453 0.0000 0.0000 0.4547
# (pet, cleaned) 0.0000 0.5398 0.4602 0.0000
#
# Signalling fraction: 0.09065181011031875
# \model{dog}{cat}{cleaned}{bathed}{pet}{0.4733973741531372}{0.5453259348869324}{0.5398418307304382}
# ============================================================
# There is a dog and a cat. The _ is being pet and the same one is being cleaned.
# There is a dog and a cat. The _ is being cleaned and the same one is being bathed.
# There is a dog and a cat. The _ is being bathed and the other one is being pet.
#                   (0, 0) (0, 1) (1, 0) (1, 1)
# (pet, cleaned) 0.4938 0.0000 0.0000 0.5062
# (cleaned, bathed) 0.4734 0.0000 0.0000 0.5266
# (bathed, pet) 0.0000 0.5346 0.4654 0.0000
#
# Signalling fraction: 0.06923353639114072
# \model{dog}{cat}{pet}{cleaned}{bathed}{0.49380001425743103}{0.4733973741531372}{0.5346167683601379}
# ============================================================

# %%
df
# Out:
#                  nouns                                          modifiers  \
# 0  [apple, strawberry]  [rotten, chilled, sold, washed, eaten, steamed...
# 1           [dog, cat]  [watched, chased, hunted, held, touched, bathe...
#
#   models contextual_models
# 0    672                 9
# 1   1008                75

# %%
import matplotlib.pyplot as plt
print(f"total number of scenarios: {len(sfs_list)}.")
print(f"total number sheaf-contextual scenarios: {len(sheaf_models_list)}({len(sheaf_models_list)/len(sfs_list)*100:.2f}%).")
plt.hist(sfs_list, bins=24)

plt.xlim((0,1))
plt.title("Signalling fractions from language examples.")
plt.show()

freq, edge = np.histogram(sfs_list, range=(0, 1), bins=24)
out1 = ''
out2 = ''
for f, e in zip(freq, edge[:-1]):
    if e < 1/6-1e-5:
        out1 += f"({e:.4f}, {f}) "
    else:
        out2 += f"({e:.4f}, {f}) "
print(f'\\histogram{{{out1}}}{{{out2}}}')
# Out:
# total number of scenarios: 1680.
# total number sheaf-contextual scenarios: 84(5.00%).
# \histogram{(0.0000, 0) (0.0417, 2) (0.0833, 16) (0.1250, 66) }{(0.1667, 38) (0.2083, 68) (0.2500, 41) (0.2917, 59) (0.3333, 92) (0.3750, 133) (0.4167, 40) (0.4583, 86) (0.5000, 33) (0.5417, 83) (0.5833, 90) (0.6250, 108) (0.6667, 152) (0.7083, 108) (0.7500, 74) (0.7917, 115) (0.8333, 142) (0.8750, 122) (0.9167, 12) (0.9583, 0) }

# %%
# print(f"total number of scenarios: {len(cbds)}.")
# plt.hist(cbds, bins=50)

# plt.title("CbD from language examples.")
# plt.show()

# %%
# print(cbd_models[0])
# print(cbd_models[0].CbD_measure())

# %%
# from contextuality.model import random_pr_like_model
# random_sfs = []
# for i in range(n_scenario):
#     model = random_pr_like_model(3)
#     random_sfs.append(model.signalling_fraction())

# plt.hist(random_sfs, bins=50)
# plt.xlim((0,1))
# plt.title("Signalling fractions from random models")
# plt.show()
